# %%
modell_a = [54.8, 57.4, 55.3, 53.4, 52.6, 55.5, 52.4, 55.7, 57.0, 54.6]
modell_b = [45.2, 70.1, 52.3, 58.1, 69.5, 37.5, 55.4, 49.7, 46.6, 90.2]

modell_a.sort()
modell_b.sort()

modell_a, modell_b
# Out:
# ([52.4, 52.6, 53.4, 54.6, 54.8, 55.3, 55.5, 55.7, 57.0, 57.4],
#  [37.5, 45.2, 46.6, 49.7, 52.3, 55.4, 58.1, 69.5, 70.1, 90.2])

# %%
a,b = round(len(modell_a) / 4.0 + 0.0000001), round(len(modell_b)/ 4.0 + 0.0000001)
a,b
# Out:
# (3, 3)

# %%
modell_a[a-1], modell_b[b-1]
# Out:
# (53.4, 46.6)
