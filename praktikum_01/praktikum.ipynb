# %%
import pandas as pd

df = pd.read_csv(
    'shoporders.csv',
    sep=',',
    encoding='utf-8',
    decimal='.',
    parse_dates=['order_date']
)

df
# Out:
#      order_id     customer_name         product category  quantity   unit  \
# 0        1150       Markus Frei     Aktenordner     Büro         1  Stück
# 1        1002     Stefan Wagner          Laptop  Elektro         1  Stück
# 2        1158     Nicole Gerber      Springseil    Sport         4  Stück
# 3        1052  Laura Zimmermann    Trinkflasche    Sport         4  Stück
# 4        1138     Julia Fischer      Laufschuhe    Sport         5  Stück
# ..        ...               ...             ...      ...       ...    ...
# 207      1034      Thomas Bauer          Tablet  Elektro         5  Stück
# 208      1117     Michael Braun  Taschenrechner     Büro         5  Stück
# 209      1015     Lukas Brunner         Drucker     Büro         1  Stück
# 210      1030    Monika Lehmann      Smartphone  Elektro         3  Stück
# 211      1115               NaN          Schuhe     Mode         3  Stück
#
#       price currency order_date shipping_country payment_method
# ...
