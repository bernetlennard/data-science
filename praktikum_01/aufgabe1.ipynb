# %%
import pandas as pd

df = pd.read_csv(
    'shoporders.csv',
    sep=',',
    encoding='utf-8',
    decimal='.',
    parse_dates=['order_date']
)

df
# Out:
# (212, 11)

# %%
# Wie viele Bestellungen enthält der Datensatz insgesamt? Wie viele Spalten hat er?
df.shape
# Out:
# payment_method
# Twint          61
# Kreditkarte    55
# PayPal         48
# Rechnung       48
# Name: count, dtype: int64

# %%
#Welche verschiedenen Zahlungsmethoden kommen im Datensatz vor, und wie häufig wird jede davon verwendet?
df['payment_method'].value_counts()
